# %%
#| hide
from pklshop.stats import *

# %% [markdown]
# # pklshop
#
# > A library for accessing and analyizing Pickleball data from pklmart

# %% [markdown]
# A demo of analyzing data Pickleball data from [pklmart](https://github.com/aspancake/pklmart)

# %% [markdown]
# ## Install

# %% [markdown]
# Install using:
# ```sh
# pip install pklshop
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# This lib provides a `Table` class you can use to create and display tables within the database

# %%
Table("match")
# Out:
# match table

# %% [markdown]
# Available tables are:

# %%
table_names
# Out:
# ['tournament', 'match']
